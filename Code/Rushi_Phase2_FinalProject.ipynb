# %% [markdown]
# # Phase Two

# %% [markdown]
# - working with manually fixed dataset to not carry any potential mistakes from Phase 1
# - recreating bcd2

# %%
import os
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy import stats
from sklearn.cluster import KMeans

# %%
!

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 825D-A908
#
#  Directory of C:\Users\rushi\GitHub\final-project\Code
#
# 12/01/2018  02:10 PM    <DIR>          .
# 12/01/2018  02:10 PM    <DIR>          ..
# 12/01/2018  02:08 PM    <DIR>          .ipynb_checkpoints
# 12/01/2018  02:02 PM           322,940 Rushi_Phase1_FinalProject.ipynb
# 12/01/2018  02:10 PM               978 Rushi_Phase2.ipynb
#                2 File(s)        323,918 bytes
#                3 Dir(s)  187,486,896,128 bytes free

# %% [markdown]
# **Change directory to where the data is**

# %%
os.chdir(r'C:\Users\rushi\GitHub\final-project\Data')

# %%
bcd = pd.read_csv('Breast-Cancer-Wisconsin-fixed.csv')

# %%
bcd.rename(columns={'A2':'clump_thick', 'A3':'uni_cell_size', 'A4':'uni_cell_shape', 'A5':'marg_adhesion', 'A6':'single_cell_size', 
                          'A7':'bare_nuc', 'A8':'bland_chromatin','A9':'normal_nuc', 'A10':'mitoses'})
# Out:
#          Scn  clump_thick  uni_cell_size  uni_cell_shape  marg_adhesion  \
# 0    1000025          5.0            1.0             1.0            1.0
# 1    1002945          5.0            4.0             4.0            5.0
# 2    1015425          3.0            1.0             1.0            1.0
# 3    1016277          6.0            8.0             8.0            1.0
# 4    1017023          4.0            1.0             1.0            3.0
# 5    1017122          8.0           10.0            10.0            8.0
# 6    1018099          1.0            1.0             1.0            1.0
# 7    1018561          2.0            1.0             2.0            1.0
# 8    1033078          2.0            1.0             1.0            1.0
# 9    1033078          4.0            2.0             1.0            1.0
# 10   1035283          1.0            1.0             1.0            1.0
# 11   1036172          2.0            1.0             1.0            1.0
# ...

# %% [markdown]
# ## Use KMeans algorithm

# %%
model = KMeans(n_clusters=4)

# %%
bcd2 = bcd[['A2','A3','A4','A5','A6','A7','A8','A9','A10']]

# %%
model.fit(bcd2.values)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ### Centroids Printed Below

# %%
print(model.cluster_centers_)
# Out:
# [[2.94493392 1.24449339 1.36563877 1.29295154 2.03964758 1.35127753
#   2.06167401 1.20044053 1.07709251]
#  [6.7625     8.3875     8.425      7.75       6.775      9.2125
#   7.375      7.7375     3.7875    ]
#  [7.23404255 4.85106383 5.04255319 4.86170213 4.11702128 9.38297872
#   5.26595745 3.78723404 1.64893617]
#  [7.46478873 7.02816901 6.67605634 4.1971831  5.53521127 3.45253521
#   5.38028169 6.81690141 2.30985915]]

# %% [markdown]
# ## Find the optimal number of clusters

# %%
inertiaRange = range(1,16)
inertiaList = []
for x in inertiaRange:
    model = KMeans(n_clusters=x)
    model.fit(bcd2.values)
    inertiaList.append(model.inertia_)

# %% [markdown]
# ### plot range and inertia
# - Add title, ylabel, xlabel

# %%
ax = plt.plot(inertiaRange,inertiaList)
plt.xlabel('# of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %% [markdown]
# ### specify the optimal number of clustes based on the inertia plot
#
# - **Based on the chart, three clusters are optimal**

# %% [markdown]
# ## Revise data variation

# %%
SDev = bcd2.std()
SDev.sort_values(ascending=True,inplace=True)
print(SDev)
# Out:
# A10    1.715078
# A6     2.214300
# A8     2.438364
# A2     2.815741
# A5     2.855379
# A4     2.971913
# A3     3.051459
# A9     3.053634
# A7     3.601852
# dtype: float64

# %% [markdown]
# ### plot standard deviation values

# %%
ax2 = plt.plot(SDev.index,SDev.values)
plt.xlabel('column names')
plt.ylabel('SDev')
# Out:
# Text(0, 0.5, 'SDev')

# %% [markdown]
# ## Implement normalization

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
kmeans = KMeans(n_clusters=3)
pipeline = make_pipeline(scaler,kmeans)
pipeline.fit(bcd2.values)
# Out:
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('kmeans', KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0))])

# %% [markdown]
# ### centroids printed below

# %%
print(kmeans.cluster_centers_)
# Out:
# [[-0.51945334 -0.61728918 -0.61702732 -0.52103625 -0.53370405 -0.60429753
#   -0.56576652 -0.54283279 -0.29912703]
#  [ 0.94324425  1.06056115  1.0579358   0.87929444  0.86029786  1.12905281
#    1.00835139  0.92952452  0.03297812]
#  [ 1.16860808  1.75960552  1.77223164  1.58294095  1.86961155  1.16434231
#    1.3895322   1.56650375  3.80910288]]
